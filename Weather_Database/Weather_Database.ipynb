# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "049f4efb51f94ddd9c2c52f781bf3567"
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=049f4efb51f94ddd9c2c52f781bf3567

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if  city not in cities:
    
        cities.append(city)

# %%
print (cities)
# Out:
# ['gat', 'punta arenas', 'belushya guba', 'upernavik', 'victoria', 'east london', 'hobart', 'haines junction', 'benguela', 'margate', 'lompoc', 'westport', 'ugoofaaru', 'bredasdorp', 'new norfolk', 'bethel', 'bireun', 'mukhen', 'jamestown', 'hobyo', 'sorong', 'arraial do cabo', 'saint george', 'komsomolskiy', 'mataura', 'deputatskiy', 'cidreira', 'ilulissat', 'kapaa', 'homer', 'campo grande', 'attawapiskat', 'busselton', 'lorengau', 'yenagoa', 'mantua', 'vaini', 'ushuaia', 'dikson', 'patan', 'hasaki', 'dakar', 'albany', 'tura', 'vardo', 'dunedin', 'kursenai', 'krivopolyanye', 'smithers', 'sant julia de loria', 'port elizabeth', 'mayo', 'tuktoyaktuk', 'beatrice', 'barrow', 'atuona', 'chokwe', 'thompson', 'tomatlan', 'liverpool', 'mpika', 'buala', 'mys shmidta', 'saskylakh', 'kahului', 'avarua', 'nuuk', 'omsukchan', 'cherskiy', 'aromashevo', 'hermanus', 'cape town', 'hilo', 'zabol', 'pisco', 'souillac', 'pevek', 'ruteng', 'manokwari', 'rikitea', 'nikolskoye', 'havre', 'san carlos de bariloche', 'baykit', 'cariati', 'clinton', 'abu jubayhah', 'jaffna', 'kodinsk', 'castro', 'presidente epitacio', 'mount gambier', 'youhao', 'para de minas', 'luderitz', 'hay river', 'sistranda', 'atar', 'kaa-khem', 'kavieng', 'lieksa', 'saint-philippe', 'santa barbara', 'houma', 'illoqqortoormiut', 'willemstad', 'lynchburg', 'bluff', 'port alfred', 'paranaiba', 'bengkulu', 'camana', 'banda aceh', 'tocopilla', 'chuy', 'bridlington', 'mama', 'beloha', 'izumo', 'tulum', 'mehamn', 'korostyshiv', 'lebu', 'kruisfontein', 'thaba nchu', 'vestmannaeyjar', 'kirakira', 'hohhot', 'thiruvananthapuram', 'warqla', 'katha', 'amapa', 'tejupilco', 'enshi', 'aklavik', 'santa maria di sala', 'buluang', 'vila velha', 'betioky', 'butaritari', 'chadiza', 'oranjestad', 'mahebourg', 'mareeba', 'hamilton', 'bengkalis', 'broken hill', 'khatanga', 'taolanaro', 'bekovo', 'ahuimanu', 'bolitoc', 'puerto ayora', 'west bay', 'saint-augustin', 'ostrovnoy', 'graaff-reinet', 'palabuhanratu', 'barentsburg', 'rocha', 'vrangel', 'mar del plata', 'palmer', 'mollendo', 'pitea', 'airai', 'shizunai', 'san cristobal', 'guayaramerin', 'miri', 'tiksi', 'arman', 'olafsvik', 'carutapera', 'tumannyy', 'iqaluit', 'georgetown', 'emba', 'qaanaaq', 'hami', 'ambagarh chauki', 'mount isa', 'carnarvon', 'freeport', 'roald', 'mendahara', 'shieli', 'surat thani', 'borovoy', 'corinto', 'puerto escondido', 'howard springs', 'dongsheng', 'naze', 'cairns', 'petropavlovsk-kamchatskiy', 'sabha', 'chokurdakh', 'san patricio', 'madanapalle', 'cabo san lucas', 'kota', 'tasiilaq', 'yellowknife', 'sitka', 'fallon', 'talnakh', 'saint-louis', 'vila franca do campo', 'bandarbeyla', 'bathsheba', 'kandrian', 'shingu', 'fairbanks', 'boueni', 'barra do garcas', 'jinchang', 'biak', 'bilma', 'jaciara', 'bac lieu', 'havoysund', 'coihueco', 'saldanha', 'turukhansk', 'ligayan', 'ribeira grande', 'bambous virieux', 'tuatapere', 'touros', 'waipawa', 'kieta', 'lewiston', 'narsaq', 'quzhou', 'bendigo', 'batemans bay', 'nemuro', 'redhakhol', 'burnie', 'basco', 'vaitupu', 'sambava', 'carquefou', 'koutsouras', 'marcona', 'dingle', 'shitkino', 'severo-kurilsk', 'skagastrond', 'baisha', 'jeremie', 'saleaula', 'catemaco', 'lavrentiya', 'longyearbyen', 'torbay', 'virginia beach', 'alta floresta', 'faanui', 'ayan', 'kodiak', 'walvis bay', 'belaya', 'kaitangata', 'laukaa', 'barda', 'vaitape', 'jalu', 'bargal', 'pahrump', 'talaya', 'sao filipe', 'ancud', 'sinnamary', 'nizhneyansk', 'caravelas', 'remedios', 'plettenberg bay', 'emerald', 'dhidhdhoo', 'necochea', 'katsuura', 'chauk', 'taburbah', 'moultrie', 'lima', 'selizharovo', 'torit', 'fortuna', 'semey', 'ghanzi', 'rock springs', 'charlestown', 'dustlik', 'rincon', 'tarudant', 'clyde river', 'poum', 'san joaquin', 'mandalgovi', 'kirovskiy', 'baruun-urt', 'cabedelo', 'khash', 'huitzo', 'gizo', 'louis trichardt', 'wah', 'santa maria', 'meulaboh', 'solovetskiy', 'parainen', 'manzhouli', 'yozgat', 'loanda', 'norsup', 'zharkent', 'henties bay', 'ponta do sol', 'yumen', 'esperance', 'fukue', 'cayen ...

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_weather_descrp = city_weather ["weather"]["Description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | gat
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | haines junction
# Processing Record 9 of Set 1 | benguela
# Processing Record 10 of Set 1 | margate
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | westport
# Processing Record 13 of Set 1 | ugoofaaru
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | bireun
# Processing Record 18 of Set 1 | mukhen
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | hobyo
# Processing Record 21 of Set 1 | sorong
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | komsomolskiy
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | homer
# Processing Record 31 of Set 1 | campo grande
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | lorengau
# Processing Record 35 of Set 1 | yenagoa
# Processing Record 36 of Set 1 | mantua
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | patan
# Processing Record 41 of Set 1 | hasaki
# Processing Record 42 of Set 1 | dakar
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | dunedin
# Processing Record 47 of Set 1 | kursenai
# Processing Record 48 of Set 1 | krivopolyanye
# City not found. Skipping...
# Processing Record 49 of Set 1 | smithers
# Processing Record 50 of Set 1 | sant julia de loria
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | mayo
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | beatrice
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | chokwe
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | tomatlan
# Processing Record 10 of Set 2 | liverpool
# Processing Record 11 of Set 2 | mpika
# Processing Record 12 of Set 2 | buala
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | nuuk
# Processing Record 18 of Set 2 | omsukchan
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | aromashevo
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | zabol
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | ruteng
# Processing Record 29 of Set 2 | manokwari
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | havre
# Processing Record 33 of Set 2 | san carlos de bariloche
# Processing Record 34 of Set 2 | baykit
# Processing Record 35 of Set 2 | cariati
# Processing Record 36 of Set 2 | clinton
# Processing Record 37 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 38 of Set 2 | jaffna
# Processing Record 39 of Set 2 | kodinsk
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | presidente epitacio
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | youhao
# Processing Record 44 of Set 2 | para de minas
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | hay river
# Processing Record 47 of Set 2 | sistranda
# Processing Record 48 of Set 2 | atar
# Processing Record 49 of Set 2 | kaa-khem
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | lieksa
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | santa barbara
# Processing Record 4 of Set 3 | houma
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | willemstad
# Processing Record 7 of Set 3 | lynchburg
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | paranaiba
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | camana
# Processing Record 13 of Set 3 | banda aceh
# Processing Record 14 of Set 3 | tocopilla
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | bridlington
# Processing Record 17 of Set 3 | mama
# Processing Record 18 of Set 3 | beloha
# Processing Record 19 of Set 3 | izumo
# Processing Record 20 of Set 3 | tulum
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | korostyshiv
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | thaba nchu
# Processing Record 26 of Set 3 | vestmannaeyjar
# Processing Record 27 of Set 3 | kirakira
# Processing Record 28 of Set 3 | hohhot
# Processing Record 29 of Set 3 | thiruvananthapuram
# Processing Record 30 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 3 | katha
# City not found. Skipping...
# Processing Record 32 of Set 3 | amapa
# Processing Record 33 of Set 3 | tejupilco
# City not found. Skipping...
# Processing Record 34 of Set 3 | enshi
# Processing Record 35 of Set 3 | aklavik
# Processing Record 36 of Set 3 | santa maria di sala
# Processing Record 37 of Set 3 | buluang
# Processing Record 38 of Set 3 | vila velha
# Processing Record 39 of Set 3 | betioky
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | chadiza
# Processing Record 42 of Set 3 | oranjestad
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | mareeba
# Processing Record 45 of Set 3 | hamilton
# Processing Record 46 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 3 | broken hill
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | bekovo
# Processing Record 1 of Set 4 | ahuimanu
# Processing Record 2 of Set 4 | bolitoc
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | west bay
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | ostrovnoy
# Processing Record 7 of Set 4 | graaff-reinet
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | vrangel
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | palmer
# Processing Record 14 of Set 4 | mollendo
# Processing Record 15 of Set 4 | pitea
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | shizunai
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | guayaramerin
# Processing Record 20 of Set 4 | miri
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | arman
# Processing Record 23 of Set 4 | olafsvik
# Processing Record 24 of Set 4 | carutapera
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | iqaluit
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | emba
# Processing Record 29 of Set 4 | qaanaaq
# Processing Record 30 of Set 4 | hami
# Processing Record 31 of Set 4 | ambagarh chauki
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | freeport
# Processing Record 35 of Set 4 | roald
# Processing Record 36 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 4 | shieli
# Processing Record 38 of Set 4 | surat thani
# Processing Record 39 of Set 4 | borovoy
# Processing Record 40 of Set 4 | corinto
# Processing Record 41 of Set 4 | puerto escondido
# Processing Record 42 of Set 4 | howard springs
# Processing Record 43 of Set 4 | dongsheng
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | cairns
# Processing Record 46 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 4 | sabha
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | san patricio
# Processing Record 50 of Set 4 | madanapalle
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | kota
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | fallon
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | saint-louis
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | kandrian
# Processing Record 13 of Set 5 | shingu
# Processing Record 14 of Set 5 | fairbanks
# Processing Record 15 of Set 5 | boueni
# Processing Record 16 of Set 5 | barra do garcas
# Processing Record 17 of Set 5 | jinchang
# Processing Record 18 of Set 5 | biak
# Processing Record 19 of Set 5 | bilma
# Processing Record 20 of Set 5 | jaciara
# Processing Record 21 of Set 5 | bac lieu
# Processing Record 22 of Set 5 | havoysund
# Processing Record 23 of Set 5 | coihueco
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | turukhansk
# Processing Record 26 of Set 5 | ligayan
# Processing Record 27 of Set 5 | ribeira grande
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | touros
# Processing Record 31 of Set 5 | waipawa
# Processing Record 32 of Set 5 | kieta
# Processing Record 33 of Set 5 | lewiston
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | quzhou
# Processing Record 36 of Set 5 | bendigo
# Processing Record 37 of Set 5 | batemans bay
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | redhakhol
# City not found. Skipping...
# Processing Record 40 of Set 5 | burnie
# Processing Record 41 of Set 5 | basco
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | sambava
# Processing Record 44 of Set 5 | carquefou
# Processing Record 45 of Set 5 | koutsouras
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | shitkino
# Processing Record 49 of Set 5 | severo-kurilsk
# Processing Record 50 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 6 | baisha
# Processing Record 2 of Set 6 | jeremie
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | catemaco
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | virginia beach
# Processing Record 9 of Set 6 | alta floresta
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | ayan
# Processing Record 12 of Set 6 | kodiak
# Processing Record 13 of Set 6 | walvis bay
# Processing Record 14 of Set 6 | belaya
# Processing Record 15 of Set 6 | kaitangata
# Processing Record 16 of Set 6 | laukaa
# Processing Record 17 of Set 6 | barda
# Processing Record 18 of Set 6 | vaitape
# Processing Record 19 of Set 6 | jalu
# Processing Record 20 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 6 | pahrump
# Processing Record 22 of Set 6 | talaya
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | sinnamary
# Processing Record 26 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 6 | caravelas
# Processing Record 28 of Set 6 | remedios
# Processing Record 29 of Set 6 | plettenberg bay
# Processing Record 30 of Set 6 | emerald
# Processing Record 31 of Set 6 | dhidhdhoo
# Processing Record 32 of Set 6 | necochea
# Processing Record 33 of Set 6 | katsuura
# Processing Record 34 of Set 6 | chauk
# Processing Record 35 of Set 6 | taburbah
# City not found. Skipping...
# Processing Record 36 of Set 6 | moultrie
# Processing Record 37 of Set 6 | lima
# Processing Record 38 of Set 6 | selizharovo
# Processing Record 39 of Set 6 | torit
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | semey
# Processing Record 42 of Set 6 | ghanzi
# Processing Record 43 of Set 6 | rock springs
# Processing Record 44 of Set 6 | charlestown
# Processing Record 45 of Set 6 | dustlik
# Processing Record 46 of Set 6 | rincon
# Processing Record 47 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | poum
# Processing Record 50 of Set 6 | san joaquin
# Processing Record 1 of Set 7 | mandalgovi
# Processing Record 2 of Set 7 | kirovskiy
# Processing Record 3 of Set 7 | baruun-urt
# Processing Record 4 of Set 7 | cabedelo
# Processing Record 5 of Set 7 | khash
# Processing Record 6 of Set 7 | huitzo
# Processing Record 7 of Set 7 | gizo
# Processing Record 8 of Set 7 | louis trichardt
# Processing Record 9 of Set 7 | wah
# Processing Record 10 of Set 7 | santa maria
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 7 | parainen
# Processing Record 14 of Set 7 | manzhouli
# Processing Record 15 of Set 7 | yozgat
# Processing Record 16 of Set 7 | loanda
# Processing Record 17 of Set 7 | norsup
# Processing Record 18 of Set 7 | zharkent
# Processing Record 19 of Set 7 | henties bay
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | yumen
# Processing Record 22 of Set 7 | esperance
# Processing Record 23 of Set 7 | fukue
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | astoria
# Processing Record 26 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 7 | angicos
# Processing Record 28 of Set 7 | gornopravdinsk
# Processing Record 29 of Set 7 | bodaybo
# Processing Record 30 of Set 7 | hithadhoo
# Processing Record 31 of Set 7 | soledar
# Processing Record 32 of Set 7 | rosamorada
# Processing Record 33 of Set 7 | tomball
# Processing Record 34 of Set 7 | provideniya
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | faya
# Processing Record 37 of Set 7 | huaihua
# Processing Record 38 of Set 7 | manicore
# Processing Record 39 of Set 7 | borama
# City not found. Skipping...
# Processing Record 40 of Set 7 | bambanglipuro
# Processing Record 41 of Set 7 | yingcheng
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | abu samrah
# Processing Record 44 of Set 7 | nome
# Processing Record 45 of Set 7 | itarema
# Processing Record 46 of Set 7 | bellavista
# Processing Record 47 of Set 7 | shenjiamen
# Processing Record 48 of Set 7 | tibati
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | north bend
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | ahipara
# Processing Record 3 of Set 8 | bam
# Processing Record 4 of Set 8 | agnibilekrou
# Processing Record 5 of Set 8 | ahtopol
# Processing Record 6 of Set 8 | sao joao da barra
# Processing Record 7 of Set 8 | kapoeta
# Processing Record 8 of Set 8 | norman wells
# Processing Record 9 of Set 8 | yar-sale
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | sabang
# Processing Record 12 of Set 8 | coos bay
# Processing Record 13 of Set 8 | lagoa
# Processing Record 14 of Set 8 | ambon
# Processing Record 15 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | odweyne
# Processing Record 18 of Set 8 | foumban
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | geraldton
# Processing Record 21 of Set 8 | sechura
# Processing Record 22 of Set 8 | sangar
# Processing Record 23 of Set 8 | svetlogorsk
# Processing Record 24 of Set 8 | kroya
# Processing Record 25 of Set 8 | longkou
# Processing Record 26 of Set 8 | sainte-rose
# Processing Record 27 of Set 8 | kysyl-syr
# Processing Record 28 of Set 8 | evensk
# Processing Record 29 of Set 8 | erenhot
# Processing Record 30 of Set 8 | moose factory
# Processing Record 31 of Set 8 | pochutla
# Processing Record 32 of Set 8 | sorland
# Processing Record 33 of Set 8 | batagay-alyta
# Processing Record 34 of Set 8 | lake havasu city
# Processing Record 35 of Set 8 | baghdad
# Processing Record 36 of Set 8 | tabou
# Processing Record 37 of Set 8 | providencia
# Processing Record 38 of Set 8 | marsa matruh
# Processing Record 39 of Set 8 | lucea
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 8 | bulgan
# Processing Record 43 of Set 8 | sydney
# Processing Record 44 of Set 8 | khandyga
# Processing Record 45 of Set 8 | viedma
# Processing Record 46 of Set 8 | berbera
# Processing Record 47 of Set 8 | vermilion
# Processing Record 48 of Set 8 | murree
# Processing Record 49 of Set 8 | kati
# Processing Record 50 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 9 | codo
# Processing Record 2 of Set 9 | carballo
# Processing Record 3 of Set 9 | andenes
# Processing Record 4 of Set 9 | hurghada
# Processing Record 5 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 9 | ponta delgada
# Processing Record 7 of Set 9 | dolores
# Processing Record 8 of Set 9 | launceston
# Processing Record 9 of Set 9 | laguna
# Processing Record 10 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | minab
# Processing Record 13 of Set 9 | saiha
# Processing Record 14 of Set 9 | micco
# Processing Record 15 of Set 9 | nanortalik
# Processing Record 16 of Set 9 | ormara
# Processing Record 17 of Set 9 | katiola
# Processing Record 18 of Set 9 | kingsport
# Processing Record 19 of Set 9 | coolum beach
# Processing Record 20 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 9 | zyryanka
# Processing Record 22 of Set 9 | neyvo-shaytanskiy
# Processing Record 23 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 9 | qaqortoq
# Processing Record 25 of Set 9 | chase
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 9 | wanning
# Processing Record 29 of Set 9 | mayumba
# Processing Record 30 of Set 9 | antalaha
# Processing Record 31 of Set 9 | esil
# Processing Record 32 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 9 | pathein
# Processing Record 34 of Set 9 | vao
# Processing Record 35 of Set 9 | borgarnes
# Processing Record 36 of Set 9 | bhag
# Processing Record 37 of Set 9 | denpasar
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | derzhavinsk
# Processing Record 40 of Set 9 | solhan
# Processing Record 41 of Set 9 | santa vitoria
# Processing Record 42 of Set 9 | yaring
# Processing Record 43 of Set 9 | maragogi
# Processing Record 44 of Set 9 | nelson bay
# Processing Record 45 of Set 9 | wewak
# Processing Record 46 of Set 9 | zinder
# Processing Record 47 of Set 9 | los llanos de aridane
# Processing Record 48 of Set 9 | pinotepa nacional
# Processing Record 49 of Set 9 | quirinopolis
# Processing Record 50 of Set 9 | libreville
# Processing Record 1 of Set 10 | aykhal
# Processing Record 2 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 10 | vila do maio
# Processing Record 4 of Set 10 | nikolayevsk-na-amure
# Processing Record 5 of Set 10 | progreso
# Processing Record 6 of Set 10 | port hardy
# Processing Record 7 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 8 of Set 10 | tessalit
# Processing Record 9 of Set 10 | anadyr
# Processing Record 10 of Set 10 | palasa
# Processing Record 11 of Set 10 | abong mbang
# Processing Record 12 of Set 10 | matane
# Processing Record 13 of Set 10 | nabire
# Processing Record 14 of Set 10 | leningradskiy
# Processing Record 15 of Set 10 | hutchinson
# Processing Record 16 of Set 10 | yerbogachen
# Processing Record 17 of Set 10 | ryugasaki
# Processing Record 18 of Set 10 | mildura
# Processing Record 19 of Set 10 | chimore
# Processing Record 20 of Set 10 | kununurra
# Processing Record 21 of Set 10 | toba
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | trairi
# Processing Record 24 of Set 10 | victor harbor
# Processing Record 25 of Set 10 | jumla
# Processing Record 26 of Set 10 | lasa
# Processing Record 27 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 28 of Set 10 | te anau
# Processing Record 29 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 10 | kargat
# Processing Record 31 of Set 10 | fort nelson
# Processing Record 32 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 10 | bezhetsk
# Processing Record 34 of Set 10 | valdez
# Processing Record 35 of Set 10 | kangaatsiaq
# Processing Record 36 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 10 | hastings
# Processing Record 38 of Set 10 | manono
# Processing Record 39 of Set 10 | rahon
# Processing Record 40 of Set 10 | lesnoy
# Processing Record 41 of Set 10 | lata
# Processing Record 42 of Set 10 | flinders
# Processing Record 43 of Set 10 | sarakhs
# Processing Record 44 of Set 10 | durazno
# Processing Record 45 of Set 10 | general pico
# Processing Record 46 of Set 10 | morehead
# Processing Record 47 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 10 | sakakah
# Processing Record 49 of Set 10 | luganville
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | husavik
# Processing Record 2 of Set 11 | kolokani
# Processing Record 3 of Set 11 | martaban
# Processing Record 4 of Set 11 | eyl
# Processing Record 5 of Set 11 | cockburn town
# Processing Record 6 of Set 11 | njinikom
# Processing Record 7 of Set 11 | comodoro rivadavia
# Processing Record 8 of Set 11 | aban
# Processing Record 9 of Set 11 | monteagudo
# Processing Record 10 of Set 11 | lodwar
# Processing Record 11 of Set 11 | tsumeb
# Processing Record 12 of Set 11 | estelle
# Processing Record 13 of Set 11 | bairiki
# Processing Record 14 of Set 11 | constitucion
# Processing Record 15 of Set 11 | shakhovskaya
# Processing Record 16 of Set 11 | raudeberg
# Processing Record 17 of Set 11 | ngozi
# Processing Record 18 of Set 11 | bestobe
# Processing Record 19 of Set 11 | rongcheng
# Processing Record 20 of Set 11 | akdagmadeni
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | katobu
# Processing Record 23 of Set 11 | huilong
# Processing Record 24 of Set 11 | kupang
# Processing Record 25 of Set 11 | port hedland
# Processing Record 26 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 11 | zhigansk
# Processing Record 28 of Set 11 | araouane
# Processing Record 29 of Set 11 | port moresby
# Processing Record 30 of Set 11 | garowe
# Processing Record 31 of Set 11 | dandong
# Processing Record 32 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 11 | coquimbo
# Processing Record 34 of Set 11 | pindwara
# Processing Record 35 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 11 | port blair
# Processing Record 37 of Set 11 | labuan
# Processing Record 38 of Set 11 | san ramon
# Processing Record 39 of Set 11 | tulsipur
# Processing Record 40 of Set 11 | vanimo
# Processing Record 41 of Set 11 | suicheng
# Processing Record 42 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 11 | srednekolymsk
# Processing Record 44 of Set 11 | jardim
# Processing Record 45 of Set 11 | boende
# Processing Record 46 of Set 11 | chicama
# Processing Record 47 of Set 11 | san quintin
# Processing Record 48 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 11 | owando
# Processing Record 50 of Set 11 | junction city
# Processing Record 1 of Set 12 | luwingu
# Processing Record 2 of Set 12 | zanjan
# Processing Record 3 of Set 12 | imperia
# Processing Record 4 of Set 12 | firozabad
# Processing Record 5 of Set 12 | pingzhuang
# Processing Record 6 of Set 12 | valdivia
# Processing Record 7 of Set 12 | avera
# Processing Record 8 of Set 12 | morros
# Processing Record 9 of Set 12 | santa luzia
# Processing Record 10 of Set 12 | sinjar
# Processing Record 11 of Set 12 | tevaitoa
# Processing Record 12 of Set 12 | goderich
# Processing Record 13 of Set 12 | bahia blanca
# Processing Record 14 of Set 12 | toamasina
# Processing Record 15 of Set 12 | singaparna
# Processing Record 16 of Set 12 | pacific grove
# Processing Record 17 of Set 12 | tambura
# Processing Record 18 of Set 12 | skarzysko-kamienna
# Processing Record 19 of Set 12 | san miguel
# Processing Record 20 of Set 12 | knysna
# Processing Record 21 of Set 12 | santa rosa
# Processing Record 22 of Set 12 | vuktyl
# Processing Record 23 of Set 12 | guerrero negro
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | eureka
# Processing Record 26 of Set 12 | jacqueville
# Processing Record 27 of Set 12 | alice springs
# Processing Record 28 of Set 12 | acarau
# Processing Record 29 of Set 12 | klaksvik
# Processing Record 30 of Set 12 | falun
# Processing Record 31 of Set 12 | bukachacha
# Processing Record 32 of Set 12 | cartagena
# Processing Record 33 of Set 12 | ayr
# Processing Record 34 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 12 | ambilobe
# Processing Record 36 of Set 12 | great yarmouth
# Processing Record 37 of Set 12 | taitung
# Processing Record 38 of Set 12 | marzuq
# Processing Record 39 of Set 12 | asyut
# Processing Record 40 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 12 | saint-leu
# Processing Record 42 of Set 12 | shakawe
# Processing Record 43 of Set 12 | morgan city
# Processing Record 44 of Set 12 | tecoanapa
# Processing Record 45 of Set 12 | the valley
# Processing Record 46 of Set 12 | penarroya-pueblonuevo
# Processing Record 47 of Set 12 | svetlyy
# Processing Record 48 of Set 12 | fernie
# Processing Record 49 of Set 12 | grand gaube
# Processing Record 50 of Set 12 | acara
# Processing Record 1 of Set 13 | birao
# Processing Record 2 of Set 13 | bonavista
# Processing Record 3 of Set 13 | acapulco
# Processing Record 4 of Set 13 | mackay
# Processing Record 5 of Set 13 | payao
# Processing Record 6 of Set 13 | bay saint louis
# Processing Record 7 of Set 13 | yulara
# Processing Record 8 of Set 13 | neepawa
# Processing Record 9 of Set 13 | tazovskiy
# Processing Record 10 of Set 13 | ballina
# Processing Record 11 of Set 13 | koulamoutou
# Processing Record 12 of Set 13 | iquitos
# Processing Record 13 of Set 13 | soyo
# Processing Record 14 of Set 13 | lazaro cardenas
# Processing Record 15 of Set 13 | pimentel
# Processing Record 16 of Set 13 | kankon
# Processing Record 17 of Set 13 | timmins
# Processing Record 18 of Set 13 | bago
# Processing Record 19 of Set 13 | nacala
# Processing Record 20 of Set 13 | kristiansund
# Processing Record 21 of Set 13 | antananarivo
# Processing Record 22 of Set 13 | chazuta
# Processing Record 23 of Set 13 | atka
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df. head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Gat  31.6100   34.7642     57.00        86           1
# 1     Punta Arenas -53.1500  -70.9167     59.00        36           0
# 2        Upernavik  72.7868  -56.1549     31.46        81         100
# 3         Victoria  22.2855  114.1577     73.00        86          91
# 4      East London -33.0153   27.9116     71.35        84         100
# 5           Hobart -42.8794  147.3294     48.99        81          90
# 6  Haines Junction  60.7522 -137.5108     12.20        28          95
# 7         Benguela -12.5763   13.4055     81.54        82          79
# 8          Margate  51.3813    1.3862     39.99        70          95
# 9           Lompoc  34.6391 -120.4579     66.00        63          94
#
#    Wind Speed Country                 Date
# 0        7.00      IL  2021-04-11 20:12:22
# 1       17.27      CL  2021-04-11 20:14:09
# 2       13.82      GL  2021-04-11 20:15:06
# 3        1.01      HK  2021-04-11 20:12:05
# 4        2.71      ZA  2021-04-11 20:15:07
# 5       12.66      AU  2021-04-11 20:11:17
# 6        3.44      CA  2021-04-11 20:14:21
# 7        4.09      AO  2021-04-11 20:14:17
# 8        5.01      GB  2021-04-11 20:10:49
# 9       21.85      US  2021-04-11 20:13:48

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0             Gat      IL  2021-04-11 20:12:22  31.6100   34.7642     57.00
# 1    Punta Arenas      CL  2021-04-11 20:14:09 -53.1500  -70.9167     59.00
# 2       Upernavik      GL  2021-04-11 20:15:06  72.7868  -56.1549     31.46
# 3        Victoria      HK  2021-04-11 20:12:05  22.2855  114.1577     73.00
# 4     East London      ZA  2021-04-11 20:15:07 -33.0153   27.9116     71.35
# ..            ...     ...                  ...      ...       ...       ...
# 567          Bago      MM  2021-04-11 20:16:18  17.3367   96.4797     80.60
# 568        Nacala      MZ  2021-04-11 20:17:49 -14.5428   40.6728     75.47
# 569  Kristiansund      NO  2021-04-11 20:17:49  63.1115    7.7320     37.40
# 570  Antananarivo      MG  2021-04-11 20:17:50 -18.9137   47.5361     64.40
# 571       Chazuta      PE  2021-04-11 20:17:50  -6.5742  -76.1367     91.40
#
#      Humidity  Cloudiness  Wind Speed
# 0          86           1        7.00
# 1          36           0       17.27
# 2          81         100       13.82
# 3          86          91        1.01
# 4          84         100        2.71
# ..        ...         ...         ...
# 567        83          40        3.44
# 568        88         100        6.64
# 569        70           2       11.50
# 570        88          20        4.61
# 571        55          40        4.61
#
# [572 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
